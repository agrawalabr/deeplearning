# %% [markdown]
# <a href="https://colab.research.google.com/github/agrawalabr/deeplearning/blob/main/CIFAR_10_ResNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import shutil
import os
os.remove("cifar-10-python.tar.gz")
shutil.rmtree("data")

# %%
# !pip install torch torchvision torchaudio
# !apt-get update -y
# !apt-get install -y nvidia-driver-535
# !apt-get install -y cuda
# !apt-get install -y libcudnn8
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   cpp-12 dctrl-tools dkms fakeroot gcc-12 keyboard-configuration libasan8 libfakeroot libfontenc1
#   libgail-common libgail18 libgcc-12-dev libgtk2.0-0 libgtk2.0-bin libgtk2.0-common libjansson4
#   liblocale-gettext-perl libnvidia-cfg1-535 libnvidia-common-535 libnvidia-compute-535
#   libnvidia-decode-535 libnvidia-encode-535 libnvidia-extra-535 libnvidia-fbc1-535 libnvidia-gl-535
#   librsvg2-common libtsan2 libxcvt0 libxfont2 libxkbfile1 nvidia-compute-utils-535 nvidia-dkms-535
#   nvidia-kernel-common-535 nvidia-kernel-source-535 nvidia-prime nvidia-settings nvidia-utils-535
#   python3-xkit screen-resolution-extra systemd-hwe-hwdb udev x11-xkb-utils xcvt xfonts-base
#   xfonts-encodings xfonts-utils xserver-common xserver-xorg-core xserver-xorg-video-nvidia-535
# Suggested packages:
#   gcc-12-locales cpp-12-doc debtags menu gcc-12-multilib gcc-12-doc gvfs xfs | xserver
#   xfonts-100dpi | xfonts-75dpi xfonts-scalable
# Recommended packages:
#   libnvidia-compute-535:i386 libnvidia-decode-535:i386 libnvidia-encode-535:i386
#   libnvidia-fbc1-535:i386 libnvidia-gl-535:i386
# The following NEW packages will be installed:
#   cpp-12 dctrl-tools dkms fakeroot gcc-12 keyboard-configuration libasan8 libfakeroot libfontenc1
#   libgail-common libgail18 libgcc-12-dev libgtk2.0-0 libgtk2.0-bin libgtk2.0-common libjansson4
#   liblocale-gettext-perl libnvidia-cfg1-535 libnvidia-common-535 libnvidia-compute-535
#   libnvidia-decode-535 libnvidia-encode-535 libnvidia-extra-535 libnvidia-fbc1-535 libnvidia-gl-535
#   librsvg2-common libtsan2 libxcvt0 libxfont2 libxkbfile1 nvidia-compute-utils-535 nvidia-dkms-535
#   nvidia-driver-535 nvidia-kernel-common-535 nvidia-kernel-source-535 nvidia-prime nvidia-settings
#   nvidia-utils-535 python3-xkit screen-resolution-extra systemd-hwe-hwdb udev x11-xkb-utils xcvt
#   xfonts-base xfonts-encodings xfonts-utils xserver-common xserver-xorg-core
#   xserver-xorg-video-nvidia-535
# 0 upgraded, 50 newly installed, 0 to remove and 31 not upgraded.
# Need to get 361 MB of archives.
# After this operation, 972 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblocale-gettext-perl amd64 1.07-4build3 [17.1 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 keyboard-configuration all 1.205ubuntu3 [206 kB]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-cfg1-535 535.230.02-0ubuntu1 [98.9 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 cpp-12 amd64 12.3.0-1ubuntu1~22.04 [10.8 MB]
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-common-535 535.230.02-0ubuntu1 [14.9 kB]
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-compute-535 535.230.02-0ubuntu1 [36.9 MB]
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-decode-535 535.230.02-0ubuntu1 [1,660 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libasan8 amd64 12.3.0-1ubuntu1~22.04 [2,442 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libtsan2 amd64 12.3.0-1ubuntu1~22.04 [2,477 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgcc-12-dev amd64 12.3.0-1ubuntu1~22.04 [2,618 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gcc-12 amd64 12.3.0-1ubuntu1~22.04 [21.7 MB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/main amd64 dctrl-tools amd64 2.24-3build2 [66.9 kB]
# Get:13 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-encode-535 535.230.02-0ubuntu1 [90.0 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 dkms all 2.8.7-2ubuntu2.2 [70.1 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 udev amd64 249.11-0ubuntu3.12 [1,557 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/main amd64 libjansson4 amd64 2.13.1-1.1build3 [32.4 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfakeroot amd64 1.28-1ubuntu1 [31.5 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy/main amd64 fakeroot amd64 1.28-1ubuntu1 [60.4 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfontenc1 amd64 1:1.1.4-1build3 [14.7 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk2.0-common all 2.24.33-2ubuntu2.1 [125 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk2.0-0 amd64 2.24.33-2ubuntu2.1 [2,038 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgail18 amd64 2.24.33-2ubuntu2.1 [15.9 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgail-common amd64 2.24.33-2ubuntu2.1 [132 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk2.0-bin amd64 2.24.33-2ubuntu2.1 [7,936 B]
# Get:25 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-extra-535 535.230.02-0ubuntu1 [256 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 librsvg2-common amd64 2.52.5+dfsg-3ubuntu0.2 [17.7 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcvt0 amd64 0.1.1-3 [5,494 B]
# Get:28 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxfont2 amd64 1:2.0.5-1build1 [94.5 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbfile1 amd64 1:1.1.0-1build3 [71.8 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-xkb-utils amd64 7.7+5build4 [172 kB]
# Get:31 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 xserver-common all 2:21.1.4-2ubuntu1.7~22.04.13 [29.1 kB]
# Get:32 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 xserver-xorg-core amd64 2:21.1.4-2ubuntu1.7~22.04.13 [1,477 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy/main amd64 nvidia-prime all 0.8.17.1 [9,956 B]
# Get:34 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-xkit all 0.5.0ubuntu5 [18.5 kB]
# Get:35 http://archive.ubuntu.com/ubuntu jammy/main amd64 screen-resolution-extra all 0.18.2 [4,396 B]
# Get:36 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 systemd-hwe-hwdb all 249.11.5 [3,228 B]
# Get:37 http://archive.ubuntu.com/ubuntu jammy/main amd64 xcvt amd64 0.1.1-3 [7,140 B]
# Get:38 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-encodings all 1:1.0.5-0ubuntu2 [578 kB]
# Get:39 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-fbc1-535 535.230.02-0ubuntu1 [51.3 kB]
# Get:40 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-utils amd64 1:7.7+6build2 [94.6 kB]
# Get:41 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-base all 1:1.0.5 [5,896 kB]
# Get:42 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-gl-535 535.230.02-0ubuntu1 [183 MB]
# Get:43 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-compute-utils-535 535.230.02-0ubuntu1 [285 kB]
# Get:44 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-kernel-source-535 535.230.02-0ubuntu1 [44.5 MB]
# Get:45 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-kernel-common-535 535.230.02-0ubuntu1 [38.4 MB]
# Get:46 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-dkms-535 535.230.02-0ubuntu1 [34.1 kB]
# Get:47 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-utils-535 535.230.02-0ubuntu1 [382 kB]
# Get:48 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  xserver-xorg-video-nvidia-535 535.230.02-0ubuntu1 [1,504 kB]
# Get:49 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-driver-535 535.230.02-0ubuntu1 [478 kB]
# Get:50 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-settings 570.124.06-0ubuntu1 [960 kB]
# Fetched 361 MB in 32s (11.4 MB/s)
# Extracting templates from packages: 100%
# Preconfiguring packages ...
# Selecting previously unselected package liblocale-gettext-perl.
# (Reading database ... 124947 files and directories currently installed.)
# Preparing to unpack .../00-liblocale-gettext-perl_1.07-4build3_amd64.deb ...
# Unpacking liblocale-gettext-perl (1.07-4build3) ...
# Selecting previously unselected package keyboard-configuration.
# Preparing to unpack .../01-keyboard-configuration_1.205ubuntu3_all.deb ...
# Unpacking keyboard-configuration (1.205ubuntu3) ...
# Selecting previously unselected package cpp-12.
# Preparing to unpack .../02-cpp-12_12.3.0-1ubuntu1~22.04_amd64.deb ...
# Unpacking cpp-12 (12.3.0-1ubuntu1~22.04) ...
# Selecting previously unselected package libasan8:amd64.
# Preparing to unpack .../03-libasan8_12.3.0-1ubuntu1~22.04_amd64.deb ...
# Unpacking libasan8:amd64 (12.3.0-1ubuntu1~22.04) ...
# Selecting previously unselected package libtsan2:amd64.
# Preparing to unpack .../04-libtsan2_12.3.0-1ubuntu1~22.04_amd64.deb ...
# Unpacking libtsan2:amd64 (12.3.0-1ubuntu1~22.04) ...
# Selecting previously unselected package libgcc-12-dev:amd64.
# Preparing to unpack .../05-libgcc-12-dev_12.3.0-1ubuntu1~22.04_amd64.deb ...
# Unpacking libgcc-12-dev:amd64 (12.3.0-1ubuntu1~22.04) ...
# Selecting previously unselected package gcc-12.
# Preparing to unpack .../06-gcc-12_12.3.0-1ubuntu1~22.04_amd64.deb ...
# Unpacking gcc-12 (12.3.0-1ubuntu1~22.04) ...
# Selecting previously unselected package dctrl-tools.
# Preparing to unpack .../07-dctrl-tools_2.24-3build2_amd64.deb ...
# Unpacking dctrl-tools (2.24-3build2) ...
# Selecting previously unselected package dkms.
# Preparing to unpack .../08-dkms_2.8.7-2ubuntu2.2_all.deb ...
# Unpacking dkms (2.8.7-2ubuntu2.2) ...
# Selecting previously unselected package udev.
# Preparing to unpack .../09-udev_249.11-0ubuntu3.12_amd64.deb ...
# Unpacking udev (249.11-0ubuntu3.12) ...
# Selecting previously unselected package libjansson4:amd64.
# Preparing to unpack .../10-libjansson4_2.13.1-1.1build3_amd64.deb ...
# Unpacking libjansson4:amd64 (2.13.1-1.1build3) ...
# Selecting previously unselected package libfakeroot:amd64.
# Preparing to unpack .../11-libfakeroot_1.28-1ubuntu1_amd64.deb ...
# Unpacking libfakeroot:amd64 (1.28-1ubuntu1) ...
# Selecting previously unselected package fakeroot.
# Preparing to unpack .../12-fakeroot_1.28-1ubuntu1_amd64.deb ...
# Unpacking fakeroot (1.28-1ubuntu1) ...
# Selecting previously unselected package libfontenc1:amd64.
# Preparing to unpack .../13-libfontenc1_1%3a1.1.4-1build3_amd64.deb ...
# Unpacking libfontenc1:amd64 (1:1.1.4-1build3) ...
# Selecting previously unselected package libgtk2.0-common.
# Preparing to unpack .../14-libgtk2.0-common_2.24.33-2ubuntu2.1_all.deb ...
# Unpacking libgtk2.0-common (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgtk2.0-0:amd64.
# Preparing to unpack .../15-libgtk2.0-0_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgtk2.0-0:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgail18:amd64.
# Preparing to unpack .../16-libgail18_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgail18:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgail-common:amd64.
# Preparing to unpack .../17-libgail-common_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgail-common:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgtk2.0-bin.
# Preparing to unpack .../18-libgtk2.0-bin_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgtk2.0-bin (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libnvidia-cfg1-535:amd64.
# Preparing to unpack .../19-libnvidia-cfg1-535_535.230.02-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-cfg1-535:amd64 (535.230.02-0ubuntu1) ...
# Selecting previously unselected package libnvidia-common-535.
# Preparing to unpack .../20-libnvidia-common-535_535.230.02-0ubuntu1_all.deb ...
# Unpacking libnvidia-common-535 (535.230.02-0ubuntu1) ...
# Selecting previously unselected package libnvidia-compute-535:amd64.
# Preparing to unpack .../21-libnvidia-compute-535_535.230.02-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-compute-535:amd64 (535.230.02-0ubuntu1) ...
# Selecting previously unselected package libnvidia-decode-535:amd64.
# Preparing to unpack .../22-libnvidia-decode-535_535.230.02-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-decode-535:amd64 (535.230.02-0ubuntu1) ...
# Selecting previously unselected package libnvidia-encode-535:amd64.
# Preparing to unpack .../23-libnvidia-encode-535_535.230.02-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-encode-535:amd64 (535.230.02-0ubuntu1) ...
# Selecting previously unselected package libnvidia-extra-535:amd64.
# Preparing to unpack .../24-libnvidia-extra-535_535.230.02-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-extra-535:amd64 (535.230.02-0ubuntu1) ...
# Selecting previously unselected package libnvidia-fbc1-535:amd64.
# Preparing to unpack .../25-libnvidia-fbc1-535_535.230.02-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-fbc1-535:amd64 (535.230.02-0ubuntu1) ...
# Selecting previously unselected package libnvidia-gl-535:amd64.
# Preparing to unpack .../26-libnvidia-gl-535_535.230.02-0ubuntu1_amd64.deb ...
# dpkg-query: no packages found matching libnvidia-gl-450
# Unpacking libnvidia-gl-535:amd64 (535.230.02-0ubuntu1) ...
# Selecting previously unselected package librsvg2-common:amd64.
# Preparing to unpack .../27-librsvg2-common_2.52.5+dfsg-3ubuntu0.2_amd64.deb ...
# Unpacking librsvg2-common:amd64 (2.52.5+dfsg-3ubuntu0.2) ...
# Selecting previously unselected package libxcvt0:amd64.
# Preparing to unpack .../28-libxcvt0_0.1.1-3_amd64.deb ...
# Unpacking libxcvt0:amd64 (0.1.1-3) ...
# Selecting previously unselected package libxfont2:amd64.
# Preparing to unpack .../29-libxfont2_1%3a2.0.5-1build1_amd64.deb ...
# Unpacking libxfont2:amd64 (1:2.0.5-1build1) ...
# Selecting previously unselected package libxkbfile1:amd64.
# Preparing to unpack .../30-libxkbfile1_1%3a1.1.0-1build3_amd64.deb ...
# Unpacking libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Selecting previously unselected package nvidia-compute-utils-535.
# Preparing to unpack .../31-nvidia-compute-utils-535_535.230.02-0ubuntu1_amd64.deb ...
# Unpacking nvidia-compute-utils-535 (535.230.02-0ubuntu1) ...
# Selecting previously unselected package nvidia-kernel-source-535.
# Preparing to unpack .../32-nvidia-kernel-source-535_535.230.02-0ubuntu1_amd64.deb ...
# Unpacking nvidia-kernel-source-535 (535.230.02-0ubuntu1) ...
# Selecting previously unselected package nvidia-kernel-common-535.
# Preparing to unpack .../33-nvidia-kernel-common-535_535.230.02-0ubuntu1_amd64.deb ...
# Unpacking nvidia-kernel-common-535 (535.230.02-0ubuntu1) ...
# Selecting previously unselected package nvidia-dkms-535.
# Preparing to unpack .../34-nvidia-dkms-535_535.230.02-0ubuntu1_amd64.deb ...
# Unpacking nvidia-dkms-535 (535.230.02-0ubuntu1) ...
# Selecting previously unselected package nvidia-utils-535.
# Preparing to unpack .../35-nvidia-utils-535_535.230.02-0ubuntu1_amd64.deb ...
# Unpacking nvidia-utils-535 (535.230.02-0ubuntu1) ...
# Selecting previously unselected package x11-xkb-utils.
# Preparing to unpack .../36-x11-xkb-utils_7.7+5build4_amd64.deb ...
# Unpacking x11-xkb-utils (7.7+5build4) ...
# Selecting previously unselected package xserver-common.
# Preparing to unpack .../37-xserver-common_2%3a21.1.4-2ubuntu1.7~22.04.13_all.deb ...
# Unpacking xserver-common (2:21.1.4-2ubuntu1.7~22.04.13) ...
# Selecting previously unselected package xserver-xorg-core.
# Preparing to unpack .../38-xserver-xorg-core_2%3a21.1.4-2ubuntu1.7~22.04.13_amd64.deb ...
# Unpacking xserver-xorg-core (2:21.1.4-2ubuntu1.7~22.04.13) ...
# Selecting previously unselected package xserver-xorg-video-nvidia-535.
# Preparing to unpack .../39-xserver-xorg-video-nvidia-535_535.230.02-0ubuntu1_amd64.deb ...
# Unpacking xserver-xorg-video-nvidia-535 (535.230.02-0ubuntu1) ...
# Selecting previously unselected package nvidia-driver-535.
# Preparing to unpack .../40-nvidia-driver-535_535.230.02-0ubuntu1_amd64.deb ...
# Unpacking nvidia-driver-535 (535.230.02-0ubuntu1) ...
# Selecting previously unselected package nvidia-prime.
# Preparing to unpack .../41-nvidia-prime_0.8.17.1_all.deb ...
# Unpacking nvidia-prime (0.8.17.1) ...
# Selecting previously unselected package python3-xkit.
# Preparing to unpack .../42-python3-xkit_0.5.0ubuntu5_all.deb ...
# Unpacking python3-xkit (0.5.0ubuntu5) ...
# Selecting previously unselected package screen-resolution-extra.
# Preparing to unpack .../43-screen-resolution-extra_0.18.2_all.deb ...
# Unpacking screen-resolution-extra (0.18.2) ...
# Selecting previously unselected package nvidia-settings.
# Preparing to unpack .../44-nvidia-settings_570.124.06-0ubuntu1_amd64.deb ...
# Unpacking nvidia-settings (570.124.06-0ubuntu1) ...
# Selecting previously unselected package systemd-hwe-hwdb.
# Preparing to unpack .../45-systemd-hwe-hwdb_249.11.5_all.deb ...
# Unpacking systemd-hwe-hwdb (249.11.5) ...
# Selecting previously unselected package xcvt.
# Preparing to unpack .../46-xcvt_0.1.1-3_amd64.deb ...
# Unpacking xcvt (0.1.1-3) ...
# Selecting previously unselected package xfonts-encodings.
# Preparing to unpack .../47-xfonts-encodings_1%3a1.0.5-0ubuntu2_all.deb ...
# Unpacking xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Selecting previously unselected package xfonts-utils.
# Preparing to unpack .../48-xfonts-utils_1%3a7.7+6build2_amd64.deb ...
# Unpacking xfonts-utils (1:7.7+6build2) ...
# Selecting previously unselected package xfonts-base.
# Preparing to unpack .../49-xfonts-base_1%3a1.0.5_all.deb ...
# Unpacking xfonts-base (1:1.0.5) ...
# Setting up cpp-12 (12.3.0-1ubuntu1~22.04) ...
# Setting up nvidia-prime (0.8.17.1) ...
# Setting up libnvidia-fbc1-535:amd64 (535.230.02-0ubuntu1) ...
# Setting up nvidia-kernel-common-535 (535.230.02-0ubuntu1) ...
# Setting up libfakeroot:amd64 (1.28-1ubuntu1) ...
# Setting up libjansson4:amd64 (2.13.1-1.1build3) ...
# Setting up fakeroot (1.28-1ubuntu1) ...
# update-alternatives: using /usr/bin/fakeroot-sysv to provide /usr/bin/fakeroot (fakeroot) in auto mode
# Setting up libfontenc1:amd64 (1:1.1.4-1build3) ...
# Setting up libnvidia-common-535 (535.230.02-0ubuntu1) ...
# Setting up xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Setting up udev (249.11-0ubuntu3.12) ...
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up libnvidia-extra-535:amd64 (535.230.02-0ubuntu1) ...
# Setting up libnvidia-cfg1-535:amd64 (535.230.02-0ubuntu1) ...
# Setting up librsvg2-common:amd64 (2.52.5+dfsg-3ubuntu0.2) ...
# Setting up systemd-hwe-hwdb (249.11.5) ...
# Setting up libasan8:amd64 (12.3.0-1ubuntu1~22.04) ...
# Setting up nvidia-kernel-source-535 (535.230.02-0ubuntu1) ...
# Setting up libnvidia-gl-535:amd64 (535.230.02-0ubuntu1) ...
# Setting up libxcvt0:amd64 (0.1.1-3) ...
# Setting up libgtk2.0-common (2.24.33-2ubuntu2.1) ...
# Setting up libnvidia-compute-535:amd64 (535.230.02-0ubuntu1) ...
# Setting up libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Setting up libtsan2:amd64 (12.3.0-1ubuntu1~22.04) ...
# Setting up python3-xkit (0.5.0ubuntu5) ...
# Setting up libxfont2:amd64 (1:2.0.5-1build1) ...
# Setting up liblocale-gettext-perl (1.07-4build3) ...
# Setting up dctrl-tools (2.24-3build2) ...
# Setting up nvidia-utils-535 (535.230.02-0ubuntu1) ...
# Setting up nvidia-compute-utils-535 (535.230.02-0ubuntu1) ...
# Warning: The home dir /nonexistent you specified can't be accessed: No such file or directory
# Adding system user `nvidia-persistenced' (UID 104) ...
# Adding new group `nvidia-persistenced' (GID 111) ...
# Adding new user `nvidia-persistenced' (UID 104) with group `nvidia-persistenced' ...
# Not creating home directory `/nonexistent'.
# Created symlink /etc/systemd/system/multi-user.target.wants/nvidia-persistenced.service → /lib/systemd/system/nvidia-persistenced.service.
# Setting up x11-xkb-utils (7.7+5build4) ...
# Setting up libgtk2.0-0:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up libnvidia-decode-535:amd64 (535.230.02-0ubuntu1) ...
# Setting up xfonts-utils (1:7.7+6build2) ...
# Setting up xcvt (0.1.1-3) ...
# Setting up xfonts-base (1:1.0.5) ...
# Setting up libgcc-12-dev:amd64 (12.3.0-1ubuntu1~22.04) ...
# Setting up screen-resolution-extra (0.18.2) ...
# Setting up libgail18:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up libgtk2.0-bin (2.24.33-2ubuntu2.1) ...
# Setting up nvidia-settings (570.124.06-0ubuntu1) ...
# Setting up xserver-common (2:21.1.4-2ubuntu1.7~22.04.13) ...
# Setting up keyboard-configuration (1.205ubuntu3) ...
# Your console font configuration will be updated the next time your system
# boots. If you want to update it now, run 'setupcon' from a virtual console.
# Setting up libgail-common:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up xserver-xorg-core (2:21.1.4-2ubuntu1.7~22.04.13) ...
# Setting up libnvidia-encode-535:amd64 (535.230.02-0ubuntu1) ...
# Setting up xserver-xorg-video-nvidia-535 (535.230.02-0ubuntu1) ...
# Setting up gcc-12 (12.3.0-1ubuntu1~22.04) ...
# Setting up dkms (2.8.7-2ubuntu2.2) ...
# Setting up nvidia-dkms-535 (535.230.02-0ubuntu1) ...
#
# A modprobe blacklist file has been created at /etc/modprobe.d to prevent Nouveau
# from loading. This can be reverted by deleting the following file:
# /etc/modprobe.d/nvidia-graphics-drivers.conf
#
# A new initrd image has also been created. To revert, please regenerate your
# initrd by running the following command after deleting the modprobe.d file:
# `/usr/sbin/initramfs -u`
#
# *****************************************************************************
# *** Reboot your computer and verify that the NVIDIA graphics driver can   ***
# *** be loaded.                                                            ***
# *****************************************************************************
#
# Loading new nvidia-535.230.02 DKMS files...
# It is likely that 6.1.85+ belongs to a chroot's host
# Building for 5.15.0-134-generic
# Building for architecture x86_64
# Building initial module for 5.15.0-134-generic
# Done.
#
# nvidia.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/5.15.0-134-generic/updates/dkms/
#
# nvidia-modeset.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/5.15.0-134-generic/updates/dkms/
#
# nvidia-drm.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/5.15.0-134-generic/updates/dkms/
#
# nvidia-peermem.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/5.15.0-134-generic/updates/dkms/
#
# nvidia-uvm.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/5.15.0-134-generic/updates/dkms/
#
# depmod...
# Setting up nvidia-driver-535 (535.230.02-0ubuntu1) ...
# Processing triggers for mailcap (3.70+nmu1ubuntu1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for dbus (1.12.20-2ubuntu4.1) ...
# Processing triggers for libgdk-pixbuf-2.0-0:amd64 (2.42.8+dfsg-1ubuntu0.3) ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   cuda-12-8 cuda-cccl-12-8 cuda-command-line-tools-12-8 cuda-compiler-12-8 cuda-crt-12-8
#   cuda-cudart-12-8 cuda-cudart-dev-12-8 cuda-cuobjdump-12-8 cuda-cupti-12-8 cuda-cupti-dev-12-8
#   cuda-cuxxfilt-12-8 cuda-demo-suite-12-8 cuda-documentation-12-8 cuda-driver-dev-12-8
#   cuda-gdb-12-8 cuda-libraries-12-8 cuda-libraries-dev-12-8 cuda-nsight-12-8
#   cuda-nsight-compute-12-8 cuda-nsight-systems-12-8 cuda-nvcc-12-8 cuda-nvdisasm-12-8
#   cuda-nvml-dev-12-8 cuda-nvprof-12-8 cuda-nvprune-12-8 cuda-nvrtc-12-8 cuda-nvrtc-dev-12-8
#   cuda-nvtx-12-8 cuda-nvvm-12-8 cuda-nvvp-12-8 cuda-opencl-12-8 cuda-opencl-dev-12-8
#   cuda-profiler-api-12-8 cuda-runtime-12-8 cuda-sanitizer-12-8 cuda-toolkit-12-8
#   cuda-toolkit-12-8-config-common cuda-tools-12-8 cuda-visual-tools-12-8 default-jre
#   default-jre-headless fonts-dejavu-core fonts-dejavu-extra gds-tools-12-8 libatk-wrapper-java
#   libatk-wrapper-java-jni libcublas-12-8 libcublas-dev-12-8 libcufft-12-8 libcufft-dev-12-8
#   libcufile-12-8 libcufile-dev-12-8 libcurand-12-8 libcurand-dev-12-8 libcusolver-12-8
#   libcusolver-dev-12-8 libcusparse-12-8 libcusparse-dev-12-8 libgudev-1.0-0 libnpp-12-8
#   libnpp-dev-12-8 libnvfatbin-12-8 libnvfatbin-dev-12-8 libnvidia-cfg1-570 libnvidia-common-570
#   libnvidia-compute-570 libnvidia-decode-570 libnvidia-encode-570 libnvidia-extra-570
#   libnvidia-fbc1-570 libnvidia-gl-570 libnvjitlink-12-8 libnvjitlink-dev-12-8 libnvjpeg-12-8
#   libnvjpeg-dev-12-8 libxcb-cursor0 libxcb-icccm4 libxcb-image0 libxcb-keysyms1 libxcb-render-util0
#   libxcb-util1 libxcb-xinerama0 libxcb-xinput0 libxcb-xkb1 libxkbcommon-x11-0 libxtst6 libxxf86dga1
#   nsight-compute-2025.1.1 nsight-systems-2024.6.2 nvidia-compute-utils-570 nvidia-dkms-570-open
#   nvidia-driver-570-open nvidia-firmware-570-570.124.06 nvidia-kernel-common-570
#   nvidia-kernel-source-570-open nvidia-modprobe nvidia-open nvidia-utils-570 openjdk-11-jre
#   switcheroo-control x11-utils xserver-xorg-video-nvidia-570
# Suggested packages:
#   nvidia-driver-570 mesa-utils
# Recommended packages:
#   libnvidia-compute-570:i386 libnvidia-decode-570:i386 libnvidia-encode-570:i386
#   libnvidia-fbc1-570:i386 libnvidia-gl-570:i386
# The following packages will be REMOVED:
#   libnvidia-cfg1-535 libnvidia-common-535 libnvidia-compute-535 libnvidia-decode-535
#   libnvidia-encode-535 libnvidia-extra-535 libnvidia-fbc1-535 libnvidia-gl-535
#   nvidia-compute-utils-535 nvidia-dkms-535 nvidia-driver-535 nvidia-kernel-common-535
#   nvidia-kernel-source-535 nvidia-prime nvidia-utils-535 xserver-xorg-video-nvidia-535
# The following NEW packages will be installed:
#   cuda cuda-12-8 cuda-cccl-12-8 cuda-command-line-tools-12-8 cuda-compiler-12-8 cuda-crt-12-8
#   cuda-cudart-12-8 cuda-cudart-dev-12-8 cuda-cuobjdump-12-8 cuda-cupti-12-8 cuda-cupti-dev-12-8
#   cuda-cuxxfilt-12-8 cuda-demo-suite-12-8 cuda-documentation-12-8 cuda-driver-dev-12-8
#   cuda-gdb-12-8 cuda-libraries-12-8 cuda-libraries-dev-12-8 cuda-nsight-12-8
#   cuda-nsight-compute-12-8 cuda-nsight-systems-12-8 cuda-nvcc-12-8 cuda-nvdisasm-12-8
#   cuda-nvml-dev-12-8 cuda-nvprof-12-8 cuda-nvprune-12-8 cuda-nvrtc-12-8 cuda-nvrtc-dev-12-8
#   cuda-nvtx-12-8 cuda-nvvm-12-8 cuda-nvvp-12-8 cuda-opencl-12-8 cuda-opencl-dev-12-8
#   cuda-profiler-api-12-8 cuda-runtime-12-8 cuda-sanitizer-12-8 cuda-toolkit-12-8
#   cuda-toolkit-12-8-config-common cuda-tools-12-8 cuda-visual-tools-12-8 default-jre
#   default-jre-headless fonts-dejavu-core fonts-dejavu-extra gds-tools-12-8 libatk-wrapper-java
#   libatk-wrapper-java-jni libcublas-12-8 libcublas-dev-12-8 libcufft-12-8 libcufft-dev-12-8
#   libcufile-12-8 libcufile-dev-12-8 libcurand-12-8 libcurand-dev-12-8 libcusolver-12-8
#   libcusolver-dev-12-8 libcusparse-12-8 libcusparse-dev-12-8 libgudev-1.0-0 libnpp-12-8
#   libnpp-dev-12-8 libnvfatbin-12-8 libnvfatbin-dev-12-8 libnvidia-cfg1-570 libnvidia-common-570
#   libnvidia-compute-570 libnvidia-decode-570 libnvidia-encode-570 libnvidia-extra-570
#   libnvidia-fbc1-570 libnvidia-gl-570 libnvjitlink-12-8 libnvjitlink-dev-12-8 libnvjpeg-12-8
#   libnvjpeg-dev-12-8 libxcb-cursor0 libxcb-icccm4 libxcb-image0 libxcb-keysyms1 libxcb-render-util0
#   libxcb-util1 libxcb-xinerama0 libxcb-xinput0 libxcb-xkb1 libxkbcommon-x11-0 libxtst6 libxxf86dga1
#   nsight-compute-2025.1.1 nsight-systems-2024.6.2 nvidia-compute-utils-570 nvidia-dkms-570-open
#   nvidia-driver-570-open nvidia-firmware-570-570.124.06 nvidia-kernel-common-570
#   nvidia-kernel-source-570-open nvidia-modprobe nvidia-open nvidia-utils-570 openjdk-11-jre
#   switcheroo-control x11-utils xserver-xorg-video-nvidia-570
# 0 upgraded, 103 newly installed, 16 to remove and 31 not upgraded.
# Need to get 3,901 MB of archives.
# After this operation, 8,478 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xinerama0 amd64 1.14-3ubuntu3 [5,414 B]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-icccm4 amd64 0.4.1-1.1build2 [11.5 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-util1 amd64 0.4.0-1build2 [11.4 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-image0 amd64 0.4.0-2 [11.5 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-keysyms1 amd64 0.4.0-1build3 [8,746 B]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-render-util0 amd64 0.3.9-1build3 [10.3 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xkb1 amd64 1.14-3ubuntu3 [32.8 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbcommon-x11-0 amd64 1.4.0-1 [14.4 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xinput0 amd64 1.14-3ubuntu3 [34.3 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libxcb-cursor0 amd64 0.1.1-4ubuntu1 [10.5 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxtst6 amd64 2:1.2.3-1build4 [13.4 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/main amd64 default-jre-headless amd64 2:1.11-72build2 [3,042 B]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 openjdk-11-jre amd64 11.0.26+4-1ubuntu1~22.04 [214 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 default-jre amd64 2:1.11-72build2 [896 B]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-core all 2.37-2build1 [1,041 kB]
# Get:16 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-toolkit-12-8-config-common 12.8.90-1 [16.4 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-extra all 2.37-2build1 [2,041 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxxf86dga1 amd64 2:1.1.5-0ubuntu3 [12.6 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-utils amd64 7.7+5build2 [206 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-wrapper-java all 0.38.0-5build1 [53.1 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-wrapper-java-jni amd64 0.38.0-5build1 [49.0 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgudev-1.0-0 amd64 1:237-2build1 [16.3 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/main amd64 switcheroo-control amd64 2.4-3build2 [16.5 kB]
# Get:24 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cudart-12-8 12.8.90-1 [170 kB]
# Get:25 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvrtc-12-8 12.8.93-1 [62.3 MB]
# Get:26 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-opencl-12-8 12.8.90-1 [24.0 kB]
# Get:27 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcublas-12-8 12.8.4.1-1 [464 MB]
# Get:28 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcufft-12-8 11.3.3.83-1 [151 MB]
# Get:29 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcufile-12-8 1.13.1.3-1 [886 kB]
# Get:30 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcurand-12-8 10.3.9.90-1 [44.8 MB]
# Get:31 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcusolver-12-8 11.7.3.90-1 [159 MB]
# Get:32 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcusparse-12-8 12.5.8.93-1 [164 MB]
# Get:33 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnpp-12-8 12.3.3.100-1 [131 MB]
# Get:34 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvjitlink-12-8 12.8.93-1 [28.3 MB]
# Get:35 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvfatbin-12-8 12.8.90-1 [743 kB]
# Get:36 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvjpeg-12-8 12.3.5.92-1 [2,910 kB]
# Get:37 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-libraries-12-8 12.8.1-1 [2,610 B]
# Get:38 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-decode-570 570.124.06-0ubuntu1 [2,434 kB]
# Get:39 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-compute-570 570.124.06-0ubuntu1 [44.1 MB]
# Get:40 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-runtime-12-8 12.8.1-1 [2,510 B]
# Get:41 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cuobjdump-12-8 12.8.90-1 [208 kB]
# Get:42 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cuxxfilt-12-8 12.8.90-1 [191 kB]
# Get:43 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cccl-12-8 12.8.90-1 [966 kB]
# Get:44 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-driver-dev-12-8 12.8.90-1 [29.1 kB]
# Get:45 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cudart-dev-12-8 12.8.90-1 [1,257 kB]
# Get:46 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvvm-12-8 12.8.93-1 [43.8 MB]
# Get:47 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-crt-12-8 12.8.93-1 [81.1 kB]
# Get:48 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvcc-12-8 12.8.93-1 [36.0 MB]
# Get:49 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvprune-12-8 12.8.90-1 [60.6 kB]
# Get:50 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-compiler-12-8 12.8.1-1 [2,506 B]
# Get:51 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-profiler-api-12-8 12.8.90-1 [18.6 kB]
# Get:52 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvrtc-dev-12-8 12.8.93-1 [53.1 MB]
# Get:53 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-opencl-dev-12-8 12.8.90-1 [89.4 kB]
# Get:54 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcublas-dev-12-8 12.8.4.1-1 [487 MB]
# Get:55 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcufft-dev-12-8 11.3.3.83-1 [302 MB]
# Get:56 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcufile-dev-12-8 1.13.1.3-1 [2,679 kB]
# Get:57 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcurand-dev-12-8 10.3.9.90-1 [44.8 MB]
# Get:58 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcusolver-dev-12-8 11.7.3.90-1 [103 MB]
# Get:59 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcusparse-dev-12-8 12.5.8.93-1 [168 MB]
# Get:60 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnpp-dev-12-8 12.3.3.100-1 [130 MB]
# Get:61 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvjitlink-dev-12-8 12.8.93-1 [26.1 MB]
# Get:62 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvfatbin-dev-12-8 12.8.90-1 [619 kB]
# Get:63 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvjpeg-dev-12-8 12.3.5.92-1 [2,612 kB]
# Get:64 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-libraries-dev-12-8 12.8.1-1 [2,650 B]
# Get:65 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cupti-12-8 12.8.90-1 [11.4 MB]
# Get:66 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cupti-dev-12-8 12.8.90-1 [4,075 kB]
# Get:67 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvdisasm-12-8 12.8.90-1 [5,088 kB]
# Get:68 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-gdb-12-8 12.8.90-1 [25.1 MB]
# Get:69 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvprof-12-8 12.8.90-1 [2,398 kB]
# Get:70 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvtx-12-8 12.8.90-1 [52.0 kB]
# Get:71 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-sanitizer-12-8 12.8.93-1 [10.3 MB]
# Get:72 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-command-line-tools-12-8 12.8.1-1 [2,542 B]
# Get:73 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nsight-compute-2025.1.1 2025.1.1.2-1 [295 MB]
# Get:74 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nsight-compute-12-8 12.8.1-1 [4,056 B]
# Get:75 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nsight-systems-2024.6.2 2024.6.2.225-246235244400v0 [374 MB]
# Get:76 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nsight-systems-12-8 12.8.1-1 [3,356 B]
# Get:77 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nsight-12-8 12.8.90-1 [119 MB]
# Get:78 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvml-dev-12-8 12.8.90-1 [127 kB]
# Get:79 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvvp-12-8 12.8.93-1 [115 MB]
# Get:80 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-visual-tools-12-8 12.8.1-1 [2,946 B]
# Get:81 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  gds-tools-12-8 1.13.1.3-1 [39.0 MB]
# Get:82 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-tools-12-8 12.8.1-1 [2,462 B]
# Get:83 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-documentation-12-8 12.8.90-1 [49.9 kB]
# Get:84 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-toolkit-12-8 12.8.1-1 [3,356 B]
# Get:85 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-demo-suite-12-8 12.8.90-1 [4,001 kB]
# Get:86 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-12-8 12.8.1-1 [2,526 B]
# Get:87 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-common-570 570.124.06-0ubuntu1 [15.9 kB]
# Get:88 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-gl-570 570.124.06-0ubuntu1 [162 MB]
# Get:89 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-kernel-source-570-open 570.124.06-0ubuntu1 [6,481 kB]
# Get:90 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-firmware-570-570.124.06 570.124.06-0ubuntu1 [64.5 MB]
# Get:91 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-modprobe 570.124.06-0ubuntu1 [14.9 kB]
# Get:92 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-kernel-common-570 570.124.06-0ubuntu1 [98.6 kB]
# Get:93 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-dkms-570-open 570.124.06-0ubuntu1 [14.9 kB]
# Get:94 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-extra-570 570.124.06-0ubuntu1 [72.7 kB]
# Get:95 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-compute-utils-570 570.124.06-0ubuntu1 [109 kB]
# Get:96 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-encode-570 570.124.06-0ubuntu1 [105 kB]
# Get:97 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-utils-570 570.124.06-0ubuntu1 [521 kB]
# Get:98 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-cfg1-570 570.124.06-0ubuntu1 [145 kB]
# Get:99 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  xserver-xorg-video-nvidia-570 570.124.06-0ubuntu1 [1,694 kB]
# Get:100 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-fbc1-570 570.124.06-0ubuntu1 [98.2 kB]
# Get:101 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-driver-570-open 570.124.06-0ubuntu1 [12.2 kB]
# Get:102 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-open 570.124.06-0ubuntu1 [2,554 B]
# Get:103 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda 12.8.1-1 [2,490 B]
# Fetched 3,901 MB in 3min 36s (18.0 MB/s)
# Extracting templates from packages: 100%
# (Reading database ... 126915 files and directories currently installed.)
# Removing nvidia-driver-535 (535.230.02-0ubuntu1) ...
# Removing xserver-xorg-video-nvidia-535 (535.230.02-0ubuntu1) ...
# Removing libnvidia-cfg1-535:amd64 (535.230.02-0ubuntu1) ...
# Removing libnvidia-gl-535:amd64 (535.230.02-0ubuntu1) ...
# Removing libnvidia-common-535 (535.230.02-0ubuntu1) ...
# Removing nvidia-utils-535 (535.230.02-0ubuntu1) ...
# Removing nvidia-compute-utils-535 (535.230.02-0ubuntu1) ...
# System has not been booted with systemd as init system (PID 1). Can't operate.
# Failed to connect to bus: Host is down
# Removing libnvidia-encode-535:amd64 (535.230.02-0ubuntu1) ...
# Removing libnvidia-decode-535:amd64 (535.230.02-0ubuntu1) ...
# Removing libnvidia-extra-535:amd64 (535.230.02-0ubuntu1) ...
# Removing libnvidia-fbc1-535:amd64 (535.230.02-0ubuntu1) ...
# Removing nvidia-dkms-535 (535.230.02-0ubuntu1) ...
# Removing all DKMS Modules
# Done.
# Removing nvidia-kernel-common-535 (535.230.02-0ubuntu1) ...
# Removing nvidia-kernel-source-535 (535.230.02-0ubuntu1) ...
# Removing nvidia-prime (0.8.17.1) ...
# Removing libnvidia-compute-535:amd64 (535.230.02-0ubuntu1) ...
# Selecting previously unselected package cuda-toolkit-12-8-config-common.
# (Reading database ... 126194 files and directories currently installed.)
# Preparing to unpack .../000-cuda-toolkit-12-8-config-common_12.8.90-1_all.deb ...
# Unpacking cuda-toolkit-12-8-config-common (12.8.90-1) ...
# Selecting previously unselected package cuda-cudart-12-8.
# Preparing to unpack .../001-cuda-cudart-12-8_12.8.90-1_amd64.deb ...
# Unpacking cuda-cudart-12-8 (12.8.90-1) ...
# Selecting previously unselected package cuda-nvrtc-12-8.
# Preparing to unpack .../002-cuda-nvrtc-12-8_12.8.93-1_amd64.deb ...
# Unpacking cuda-nvrtc-12-8 (12.8.93-1) ...
# Selecting previously unselected package cuda-opencl-12-8.
# Preparing to unpack .../003-cuda-opencl-12-8_12.8.90-1_amd64.deb ...
# Unpacking cuda-opencl-12-8 (12.8.90-1) ...
# Selecting previously unselected package libcublas-12-8.
# Preparing to unpack .../004-libcublas-12-8_12.8.4.1-1_amd64.deb ...
# Unpacking libcublas-12-8 (12.8.4.1-1) ...
# Selecting previously unselected package libcufft-12-8.
# Preparing to unpack .../005-libcufft-12-8_11.3.3.83-1_amd64.deb ...
# Unpacking libcufft-12-8 (11.3.3.83-1) ...
# Selecting previously unselected package libcufile-12-8.
# Preparing to unpack .../006-libcufile-12-8_1.13.1.3-1_amd64.deb ...
# Unpacking libcufile-12-8 (1.13.1.3-1) ...
# Selecting previously unselected package libcurand-12-8.
# Preparing to unpack .../007-libcurand-12-8_10.3.9.90-1_amd64.deb ...
# Unpacking libcurand-12-8 (10.3.9.90-1) ...
# Selecting previously unselected package libcusolver-12-8.
# Preparing to unpack .../008-libcusolver-12-8_11.7.3.90-1_amd64.deb ...
# Unpacking libcusolver-12-8 (11.7.3.90-1) ...
# Selecting previously unselected package libcusparse-12-8.
# Preparing to unpack .../009-libcusparse-12-8_12.5.8.93-1_amd64.deb ...
# Unpacking libcusparse-12-8 (12.5.8.93-1) ...
# Selecting previously unselected package libnpp-12-8.
# Preparing to unpack .../010-libnpp-12-8_12.3.3.100-1_amd64.deb ...
# Unpacking libnpp-12-8 (12.3.3.100-1) ...
# Selecting previously unselected package libnvjitlink-12-8.
# Preparing to unpack .../011-libnvjitlink-12-8_12.8.93-1_amd64.deb ...
# Unpacking libnvjitlink-12-8 (12.8.93-1) ...
# Selecting previously unselected package libnvfatbin-12-8.
# Preparing to unpack .../012-libnvfatbin-12-8_12.8.90-1_amd64.deb ...
# Unpacking libnvfatbin-12-8 (12.8.90-1) ...
# Selecting previously unselected package libnvjpeg-12-8.
# Preparing to unpack .../013-libnvjpeg-12-8_12.3.5.92-1_amd64.deb ...
# Unpacking libnvjpeg-12-8 (12.3.5.92-1) ...
# Selecting previously unselected package cuda-libraries-12-8.
# Preparing to unpack .../014-cuda-libraries-12-8_12.8.1-1_amd64.deb ...
# Unpacking cuda-libraries-12-8 (12.8.1-1) ...
# Selecting previously unselected package libnvidia-decode-570:amd64.
# Preparing to unpack .../015-libnvidia-decode-570_570.124.06-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-decode-570:amd64 (570.124.06-0ubuntu1) ...
# Selecting previously unselected package libnvidia-compute-570:amd64.
# Preparing to unpack .../016-libnvidia-compute-570_570.124.06-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-compute-570:amd64 (570.124.06-0ubuntu1) ...
# Selecting previously unselected package cuda-runtime-12-8.
# Preparing to unpack .../017-cuda-runtime-12-8_12.8.1-1_amd64.deb ...
# Unpacking cuda-runtime-12-8 (12.8.1-1) ...
# Selecting previously unselected package cuda-cuobjdump-12-8.
# Preparing to unpack .../018-cuda-cuobjdump-12-8_12.8.90-1_amd64.deb ...
# Unpacking cuda-cuobjdump-12-8 (12.8.90-1) ...
# Selecting previously unselected package cuda-cuxxfilt-12-8.
# Preparing to unpack .../019-cuda-cuxxfilt-12-8_12.8.90-1_amd64.deb ...
# Unpacking cuda-cuxxfilt-12-8 (12.8.90-1) ...
# Selecting previously unselected package cuda-cccl-12-8.
# Preparing to unpack .../020-cuda-cccl-12-8_12.8.90-1_amd64.deb ...
# Unpacking cuda-cccl-12-8 (12.8.90-1) ...
# Selecting previously unselected package cuda-driver-dev-12-8.
# Preparing to unpack .../021-cuda-driver-dev-12-8_12.8.90-1_amd64.deb ...
# Unpacking cuda-driver-dev-12-8 (12.8.90-1) ...
# Selecting previously unselected package cuda-cudart-dev-12-8.
# Preparing to unpack .../022-cuda-cudart-dev-12-8_12.8.90-1_amd64.deb ...
# Unpacking cuda-cudart-dev-12-8 (12.8.90-1) ...
# Selecting previously unselected package cuda-nvvm-12-8.
# Preparing to unpack .../023-cuda-nvvm-12-8_12.8.93-1_amd64.deb ...
# Unpacking cuda-nvvm-12-8 (12.8.93-1) ...
# Selecting previously unselected package cuda-crt-12-8.
# Preparing to unpack .../024-cuda-crt-12-8_12.8.93-1_amd64.deb ...
# Unpacking cuda-crt-12-8 (12.8.93-1) ...
# Selecting previously unselected package cuda-nvcc-12-8.
# ...
# Preparing to unpack .../068-cuda-nsight-12-8_12.8.90-1_amd64.deb ...
# Unpacking cuda-nsight-12-8 (12.8.90-1) ...
# Selecting previously unselected package cuda-nvml-dev-12-8.
# Preparing to unpack .../069-cuda-nvml-dev-12-8_12.8.90-1_amd64.deb ...
# Unpacking cuda-nvml-dev-12-8 (12.8.90-1) ...
# Selecting previously unselected package cuda-nvvp-12-8.
# Preparing to unpack .../070-cuda-nvvp-12-8_12.8.93-1_amd64.deb ...
# Unpacking cuda-nvvp-12-8 (12.8.93-1) ...
# Selecting previously unselected package cuda-visual-tools-12-8.
# Preparing to unpack .../071-cuda-visual-tools-12-8_12.8.1-1_amd64.deb ...
# Unpacking cuda-visual-tools-12-8 (12.8.1-1) ...
# Selecting previously unselected package gds-tools-12-8.
# Preparing to unpack .../072-gds-tools-12-8_1.13.1.3-1_amd64.deb ...
# Unpacking gds-tools-12-8 (1.13.1.3-1) ...
# Selecting previously unselected package cuda-tools-12-8.
# Preparing to unpack .../073-cuda-tools-12-8_12.8.1-1_amd64.deb ...
# Unpacking cuda-tools-12-8 (12.8.1-1) ...
# Selecting previously unselected package cuda-documentation-12-8.
# Preparing to unpack .../074-cuda-documentation-12-8_12.8.90-1_amd64.deb ...
# Unpacking cuda-documentation-12-8 (12.8.90-1) ...
# Selecting previously unselected package cuda-toolkit-12-8.
# Preparing to unpack .../075-cuda-toolkit-12-8_12.8.1-1_amd64.deb ...
# Unpacking cuda-toolkit-12-8 (12.8.1-1) ...
# Selecting previously unselected package cuda-demo-suite-12-8.
# Preparing to unpack .../076-cuda-demo-suite-12-8_12.8.90-1_amd64.deb ...
# Unpacking cuda-demo-suite-12-8 (12.8.90-1) ...
# Selecting previously unselected package cuda-12-8.
# Preparing to unpack .../077-cuda-12-8_12.8.1-1_amd64.deb ...
# Unpacking cuda-12-8 (12.8.1-1) ...
# Selecting previously unselected package libnvidia-common-570.
# Preparing to unpack .../078-libnvidia-common-570_570.124.06-0ubuntu1_all.deb ...
# Unpacking libnvidia-common-570 (570.124.06-0ubuntu1) ...
# Selecting previously unselected package libnvidia-gl-570:amd64.
# Preparing to unpack .../079-libnvidia-gl-570_570.124.06-0ubuntu1_amd64.deb ...
# dpkg-query: no packages found matching libnvidia-gl-535
# Unpacking libnvidia-gl-570:amd64 (570.124.06-0ubuntu1) ...
# Selecting previously unselected package nvidia-kernel-source-570-open.
# Preparing to unpack .../080-nvidia-kernel-source-570-open_570.124.06-0ubuntu1_amd64.deb ...
# Unpacking nvidia-kernel-source-570-open (570.124.06-0ubuntu1) ...
# Selecting previously unselected package nvidia-firmware-570-570.124.06.
# Preparing to unpack .../081-nvidia-firmware-570-570.124.06_570.124.06-0ubuntu1_amd64.deb ...
# Unpacking nvidia-firmware-570-570.124.06 (570.124.06-0ubuntu1) ...
# Selecting previously unselected package nvidia-modprobe.
# Preparing to unpack .../082-nvidia-modprobe_570.124.06-0ubuntu1_amd64.deb ...
# Unpacking nvidia-modprobe (570.124.06-0ubuntu1) ...
# Selecting previously unselected package nvidia-kernel-common-570.
# Preparing to unpack .../083-nvidia-kernel-common-570_570.124.06-0ubuntu1_amd64.deb ...
# Unpacking nvidia-kernel-common-570 (570.124.06-0ubuntu1) ...
# Selecting previously unselected package nvidia-dkms-570-open.
# Preparing to unpack .../084-nvidia-dkms-570-open_570.124.06-0ubuntu1_amd64.deb ...
# Unpacking nvidia-dkms-570-open (570.124.06-0ubuntu1) ...
# Selecting previously unselected package libnvidia-extra-570:amd64.
# Preparing to unpack .../085-libnvidia-extra-570_570.124.06-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-extra-570:amd64 (570.124.06-0ubuntu1) ...
# Selecting previously unselected package nvidia-compute-utils-570.
# Preparing to unpack .../086-nvidia-compute-utils-570_570.124.06-0ubuntu1_amd64.deb ...
# Unpacking nvidia-compute-utils-570 (570.124.06-0ubuntu1) ...
# Selecting previously unselected package libnvidia-encode-570:amd64.
# Preparing to unpack .../087-libnvidia-encode-570_570.124.06-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-encode-570:amd64 (570.124.06-0ubuntu1) ...
# Selecting previously unselected package nvidia-utils-570.
# Preparing to unpack .../088-nvidia-utils-570_570.124.06-0ubuntu1_amd64.deb ...
# Unpacking nvidia-utils-570 (570.124.06-0ubuntu1) ...
# Selecting previously unselected package libnvidia-cfg1-570:amd64.
# Preparing to unpack .../089-libnvidia-cfg1-570_570.124.06-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-cfg1-570:amd64 (570.124.06-0ubuntu1) ...
# Selecting previously unselected package xserver-xorg-video-nvidia-570.
# Preparing to unpack .../090-xserver-xorg-video-nvidia-570_570.124.06-0ubuntu1_amd64.deb ...
# Unpacking xserver-xorg-video-nvidia-570 (570.124.06-0ubuntu1) ...
# Selecting previously unselected package libnvidia-fbc1-570:amd64.
# Preparing to unpack .../091-libnvidia-fbc1-570_570.124.06-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-fbc1-570:amd64 (570.124.06-0ubuntu1) ...
# Selecting previously unselected package nvidia-driver-570-open.
# Preparing to unpack .../092-nvidia-driver-570-open_570.124.06-0ubuntu1_amd64.deb ...
# Unpacking nvidia-driver-570-open (570.124.06-0ubuntu1) ...
# Selecting previously unselected package nvidia-open.
# Preparing to unpack .../093-nvidia-open_570.124.06-0ubuntu1_amd64.deb ...
# Unpacking nvidia-open (570.124.06-0ubuntu1) ...
# Selecting previously unselected package cuda.
# Preparing to unpack .../094-cuda_12.8.1-1_amd64.deb ...
# Unpacking cuda (12.8.1-1) ...
# Selecting previously unselected package fonts-dejavu-core.
# Preparing to unpack .../095-fonts-dejavu-core_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-core (2.37-2build1) ...
# Selecting previously unselected package fonts-dejavu-extra.
# Preparing to unpack .../096-fonts-dejavu-extra_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-extra (2.37-2build1) ...
# Selecting previously unselected package libxxf86dga1:amd64.
# Preparing to unpack .../097-libxxf86dga1_2%3a1.1.5-0ubuntu3_amd64.deb ...
# Unpacking libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Selecting previously unselected package x11-utils.
# Preparing to unpack .../098-x11-utils_7.7+5build2_amd64.deb ...
# Unpacking x11-utils (7.7+5build2) ...
# Selecting previously unselected package libatk-wrapper-java.
# Preparing to unpack .../099-libatk-wrapper-java_0.38.0-5build1_all.deb ...
# Unpacking libatk-wrapper-java (0.38.0-5build1) ...
# Selecting previously unselected package libatk-wrapper-java-jni:amd64.
# Preparing to unpack .../100-libatk-wrapper-java-jni_0.38.0-5build1_amd64.deb ...
# Unpacking libatk-wrapper-java-jni:amd64 (0.38.0-5build1) ...
# Selecting previously unselected package libgudev-1.0-0:amd64.
# Preparing to unpack .../101-libgudev-1.0-0_1%3a237-2build1_amd64.deb ...
# Unpacking libgudev-1.0-0:amd64 (1:237-2build1) ...
# Selecting previously unselected package switcheroo-control.
# Preparing to unpack .../102-switcheroo-control_2.4-3build2_amd64.deb ...
# Unpacking switcheroo-control (2.4-3build2) ...
# Setting up nvidia-firmware-570-570.124.06 (570.124.06-0ubuntu1) ...
# Setting up cuda-nvprof-12-8 (12.8.90-1) ...
# Setting up nvidia-kernel-source-570-open (570.124.06-0ubuntu1) ...
# Setting up default-jre-headless (2:1.11-72build2) ...
# Setting up libxcb-xinput0:amd64 (1.14-3ubuntu3) ...
# Setting up cuda-cuobjdump-12-8 (12.8.90-1) ...
# Setting up cuda-nvrtc-12-8 (12.8.93-1) ...
# Setting up libnvidia-extra-570:amd64 (570.124.06-0ubuntu1) ...
# Setting up cuda-sanitizer-12-8 (12.8.93-1) ...
# Setting up cuda-nvvm-12-8 (12.8.93-1) ...
# Setting up cuda-nvprune-12-8 (12.8.90-1) ...
# Setting up libxtst6:amd64 (2:1.2.3-1build4) ...
# Setting up cuda-cupti-12-8 (12.8.90-1) ...
# Setting up libxcb-keysyms1:amd64 (0.4.0-1build3) ...
# Setting up libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Setting up cuda-nvml-dev-12-8 (12.8.90-1) ...
# Setting up libxcb-render-util0:amd64 (0.3.9-1build3) ...
# Setting up openjdk-11-jre:amd64 (11.0.26+4-1ubuntu1~22.04) ...
# Setting up cuda-toolkit-12-8-config-common (12.8.90-1) ...
# Setting alternatives
# update-alternatives: using /usr/local/cuda-12.8 to provide /usr/local/cuda (cuda) in auto mode
# update-alternatives: using /usr/local/cuda-12.8 to provide /usr/local/cuda-12 (cuda-12) in auto mode
# Setting up libxcb-icccm4:amd64 (0.4.1-1.1build2) ...
# Setting up default-jre (2:1.11-72build2) ...
# Setting up cuda-nvrtc-dev-12-8 (12.8.93-1) ...
# Setting up libxcb-util1:amd64 (0.4.0-1build2) ...
# Setting up libxcb-xkb1:amd64 (1.14-3ubuntu3) ...
# Setting up nvidia-modprobe (570.124.06-0ubuntu1) ...
# Setting up libxcb-image0:amd64 (0.4.0-2) ...
# Setting up cuda-driver-dev-12-8 (12.8.90-1) ...
# Setting up libnvidia-common-570 (570.124.06-0ubuntu1) ...
# Setting up cuda-documentation-12-8 (12.8.90-1) ...
# Setting up libxcb-xinerama0:amd64 (1.14-3ubuntu3) ...
# Setting up cuda-nvvp-12-8 (12.8.93-1) ...
# Setting up libxcb-cursor0:amd64 (0.1.1-4ubuntu1) ...
# Setting up cuda-profiler-api-12-8 (12.8.90-1) ...
# Setting up libnvidia-cfg1-570:amd64 (570.124.06-0ubuntu1) ...
# Setting up libxkbcommon-x11-0:amd64 (1.4.0-1) ...
# Setting up libcusolver-12-8 (11.7.3.90-1) ...
# Setting up cuda-demo-suite-12-8 (12.8.90-1) ...
# Setting up fonts-dejavu-core (2.37-2build1) ...
# Setting up cuda-nvdisasm-12-8 (12.8.90-1) ...
# Setting up libnvfatbin-12-8 (12.8.90-1) ...
# Setting up libnvjpeg-12-8 (12.3.5.92-1) ...
# Setting up fonts-dejavu-extra (2.37-2build1) ...
# Setting up libcusolver-dev-12-8 (11.7.3.90-1) ...
# Setting up libcufile-12-8 (1.13.1.3-1) ...
# Setting alternatives
# update-alternatives: using /usr/local/cuda-12.8/gds/cufile.json to provide /etc/cufile.json (cufile.json) in auto mode
# Setting up x11-utils (7.7+5build2) ...
# Setting up cuda-cuxxfilt-12-8 (12.8.90-1) ...
# Setting up cuda-nvtx-12-8 (12.8.90-1) ...
# Setting up libnvfatbin-dev-12-8 (12.8.90-1) ...
# Setting up libatk-wrapper-java (0.38.0-5build1) ...
# Setting up cuda-cccl-12-8 (12.8.90-1) ...
# Setting up cuda-cudart-12-8 (12.8.90-1) ...
# Setting up cuda-cupti-dev-12-8 (12.8.90-1) ...
# Setting up libnvidia-fbc1-570:amd64 (570.124.06-0ubuntu1) ...
# Setting up libgudev-1.0-0:amd64 (1:237-2build1) ...
# Setting up xserver-xorg-video-nvidia-570 (570.124.06-0ubuntu1) ...
# Setting up cuda-nsight-12-8 (12.8.90-1) ...
# Setting up cuda-cudart-dev-12-8 (12.8.90-1) ...
# Setting up gds-tools-12-8 (1.13.1.3-1) ...
# Setting up nsight-compute-2025.1.1 (2025.1.1.2-1) ...
# Setting up nvidia-kernel-common-570 (570.124.06-0ubuntu1) ...
# Setting up cuda-crt-12-8 (12.8.93-1) ...
# Setting up libcufft-12-8 (11.3.3.83-1) ...
# Setting up libcublas-12-8 (12.8.4.1-1) ...
# Setting up libcusparse-12-8 (12.5.8.93-1) ...
# Setting up libnvjpeg-dev-12-8 (12.3.5.92-1) ...
# Setting up libnvidia-gl-570:amd64 (570.124.06-0ubuntu1) ...
# Setting up libnvjitlink-12-8 (12.8.93-1) ...
# Setting up libcufile-dev-12-8 (1.13.1.3-1) ...
# Setting up libcurand-12-8 (10.3.9.90-1) ...
# Setting up libcufft-dev-12-8 (11.3.3.83-1) ...
# Setting up nvidia-dkms-570-open (570.124.06-0ubuntu1) ...
# Loading new nvidia-570.124.06 DKMS files...
# It is likely that 6.1.85+ belongs to a chroot's host
# Building for 5.15.0-134-generic
# Building for architecture x86_64
# Building initial module for 5.15.0-134-generic
# Done.
#
# nvidia.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/5.15.0-134-generic/updates/dkms/
#
# nvidia-modeset.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/5.15.0-134-generic/updates/dkms/
#
# nvidia-drm.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/5.15.0-134-generic/updates/dkms/
#
# nvidia-uvm.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/5.15.0-134-generic/updates/dkms/
#
# nvidia-peermem.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/5.15.0-134-generic/updates/dkms/
#
# depmod...
# Setting up libnpp-12-8 (12.3.3.100-1) ...
# Setting up libnpp-dev-12-8 (12.3.3.100-1) ...
# Setting up cuda-opencl-12-8 (12.8.90-1) ...
# Setting up libatk-wrapper-java-jni:amd64 (0.38.0-5build1) ...
# Setting up cuda-gdb-12-8 (12.8.90-1) ...
# Setting up nsight-systems-2024.6.2 (2024.6.2.225-246235244400v0) ...
# update-alternatives: using /opt/nvidia/nsight-systems/2024.6.2/target-linux-x64/nsys to provide /usr/local/bin/nsys (nsys) in auto mode
# update-alternatives: using /opt/nvidia/nsight-systems/2024.6.2/host-linux-x64/nsys-ui to provide /usr/local/bin/nsys-ui (nsys-ui) in auto mode
# Setting up libnvjitlink-dev-12-8 (12.8.93-1) ...
# Setting up cuda-libraries-12-8 (12.8.1-1) ...
# Setting up cuda-nsight-systems-12-8 (12.8.1-1) ...
# Setting up libcurand-dev-12-8 (10.3.9.90-1) ...
# Setting up cuda-nsight-compute-12-8 (12.8.1-1) ...
# Setting up switcheroo-control (2.4-3build2) ...
# Created symlink /etc/systemd/system/graphical.target.wants/switcheroo-control.service → /lib/systemd/system/switcheroo-control.service.
# Setting up libcusparse-dev-12-8 (12.5.8.93-1) ...
# Setting up libcublas-dev-12-8 (12.8.4.1-1) ...
# Setting up cuda-nvcc-12-8 (12.8.93-1) ...
# Setting up cuda-opencl-dev-12-8 (12.8.90-1) ...
# Setting up cuda-command-line-tools-12-8 (12.8.1-1) ...
# Setting up cuda-compiler-12-8 (12.8.1-1) ...
# Setting up cuda-libraries-dev-12-8 (12.8.1-1) ...
# Setting up cuda-visual-tools-12-8 (12.8.1-1) ...
# Setting up cuda-tools-12-8 (12.8.1-1) ...
# Setting up cuda-toolkit-12-8 (12.8.1-1) ...
# Setting up libnvidia-compute-570:amd64 (570.124.06-0ubuntu1) ...
# Setting up libnvidia-decode-570:amd64 (570.124.06-0ubuntu1) ...
# Setting up nvidia-utils-570 (570.124.06-0ubuntu1) ...
# Setting up nvidia-compute-utils-570 (570.124.06-0ubuntu1) ...
# Setting up cuda-runtime-12-8 (12.8.1-1) ...
# Setting up libnvidia-encode-570:amd64 (570.124.06-0ubuntu1) ...
# Setting up cuda-12-8 (12.8.1-1) ...
# Setting up nvidia-driver-570-open (570.124.06-0ubuntu1) ...
# Setting up nvidia-open (570.124.06-0ubuntu1) ...
# Setting up cuda (12.8.1-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for dbus (1.12.20-2ubuntu4.1) ...
# Processing triggers for udev (249.11-0ubuntu3.12) ...
# Processing triggers for mailcap (3.70+nmu1ubuntu1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   libcudnn8
# 0 upgraded, 1 newly installed, 0 to remove and 31 not upgraded.
# Need to get 444 MB of archives.
# After this operation, 1,099 MB of additional disk space will be used.
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcudnn8 8.9.7.29-1+cuda12.2 [444 MB]
# Fetched 444 MB in 9s (50.4 MB/s)
# Selecting previously unselected package libcudnn8.
# (Reading database ... 133500 files and directories currently installed.)
# Preparing to unpack .../libcudnn8_8.9.7.29-1+cuda12.2_amd64.deb ...
# Unpacking libcudnn8 (8.9.7.29-1+cuda12.2) ...
# Setting up libcudnn8 (8.9.7.29-1+cuda12.2) ...

# %%
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision import datasets
from torchvision import transforms
from torch.utils.data.sampler import SubsetRandomSampler

# %%
trainData = datasets.CIFAR10('data', train=True, download=True, transform=transforms.ToTensor())
testData = datasets.CIFAR10('data', train=False, download=True, transform=transforms.ToTensor())
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to data/cifar-10-python.tar.gz
# 100%|██████████| 170M/170M [00:10<00:00, 15.5MB/s]
# Extracting data/cifar-10-python.tar.gz to data
# Files already downloaded and verified

# %%
batch_size = 64
trainDataLoader = DataLoader(trainData, batch_size=batch_size, shuffle=True)
testDataLoader = DataLoader(testData, batch_size=batch_size, shuffle=True)

# %%
class BasicBlock(nn.Module):
  def __init__(self, in_channels, out_channels, kernel_size, stride, padding):
    super().__init__()
    self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False)
    self.bn1 = nn.BatchNorm2d(out_channels)
    self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding=1, bias=False)
    self.bn2 = nn.BatchNorm2d(out_channels)

    self.shortcut = nn.Sequential()
    if stride != 1 or in_channels != self.expansion*out_channels:
        self.shortcut = nn.Sequential(nn.Conv2d(in_channels, self.expansion*out_channels, kernel_size=1, stride=stride, bias=False),
                        nn.BatchNorm2d(self.expansion*out_channels))

  def forward(self, x):
    x = F.relu(self.conv1(self.bn1(x)))
    x = self.bn2(self.conv2(x))
    x += self.shortcut

class ConvLayers(nn.Module):
  def __init__(self, in_channels, out_channels, kernel_size, stride, padding):
    super().__init__()
    self.conv1 = ConvBlock(in_channels, out_channels, kernel_size, stride, padding, first=True)
    self.conv2 = ConvBlock(out_channels, out_channels, kernel_size, 1, padding)

  def forward(self, x):
    x = self.bn(self.conv(x))
    return x

# %%
class block(nn.Module):
  def __init__(self, in_channels, out_channels, identity_downsample=None, stride=1):
    super().__init__()
    self.expansion = 4
    self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=1, padding=0)
    self.bn1 = nn.BatchNorm2d(out_channels)
    self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=stride, padding=1)
    self.bn2 = nn.BatchNorm2d(out_channels)
    self.conv3 = nn.Conv2d(out_channels, out_channels*self.expansion, kernel_size=1, stride=1, padding=0)
    self.bn3 = nn.BatchNorm2d(out_channels*self.expansion)
    self.relu = nn.ReLU()
    self.identity_downsample = identity_downsample

  def forward(self, x):
    identity = x.clone()

    x = self.conv1(x)
    x = self.bn1(x)
    x = self.relu(x)
    x = self.conv2(x)
    x = self.bn2(x)
    x = self.relu(x)
    x = self.conv3(x)
    x = self.bn3(x)

    if self.identity_downsample is not None:
      identity = self.identity_downsample(identity)

    x += identity
    x = self.relu(x)
    return x

# %%
class ResNet(nn.Module):
  def __init__(self, block, layers, image_channels, num_classes):
    super().__init__()
    self.in_channels = 64
    self.conv1 = nn.Conv2d(image_channels, 64, kernel_size=7, stride=2, padding=3)
    self.bn1 = nn.BatchNorm2d(64)
    self.relu = nn.ReLU()
    self.maxpool = nn.MaxPool2d(kernel_size=3, stride=2, padding=1)

    def make_layers(self, block, num_residual_blocks, out_channels, stride):
      identity_downsample = None
      layers = []

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(
            in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                               stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes,
                          kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class Bottleneck(nn.Module):
    expansion = 4

    def __init__(self, in_planes, planes, stride=1):
        super(Bottleneck, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                               stride=stride, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.conv3 = nn.Conv2d(planes, self.expansion *
                               planes, kernel_size=1, bias=False)
        self.bn3 = nn.BatchNorm2d(self.expansion*planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes,
                          kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv3(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=3,
                               stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512*block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out


def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])


def ResNet34():
    return ResNet(BasicBlock, [3, 4, 6, 3])


def ResNet50():
    return ResNet(Bottleneck, [3, 4, 6, 3])


def ResNet101():
    return ResNet(Bottleneck, [3, 4, 23, 3])


def ResNet152():
    return ResNet(Bottleneck, [3, 8, 36, 3])


def test():
    net = ResNet18()
    y = net(torch.randn(1, 3, 32, 32))
    print(y.size())

# test()
